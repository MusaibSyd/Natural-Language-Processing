# %% [markdown]
# <a href="https://colab.research.google.com/github/MusaibSyd/Natural-Language-Processing/blob/main/Article_Recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction import text
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/articles.csv", encoding='latin1')

# %%
pd.set_option('display.max_colwidth', -1)
data.iloc[1].head()
# Out:
# <ipython-input-3-fc92444f2cb4>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# Article    The performance of a machine learning algorithm on a particular dataset often depends on whether the features of the dataset satisfies the assumptions of that machine learning algorithm. Not all machine learning algorithms have assumptions that differentiate them from each other. So, in this article, I will take you through the assumptions of machine learning algorithms.
# Title      Assumptions of Machine Learning Algorithms
# Name: 1, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Article  34 non-null     object
#  1   Title    34 non-null     object
# dtypes: object(2)
# memory usage: 672.0+ bytes

# %%
articles = data["Article"].tolist()

# %%
articles[0]
# Out:
# 'Data analysis is the process of inspecting and exploring data generated by a particular population to find the information needed to make decisions and draw conclusions. With the use of data in decision making, most businesses today need data analysts. So, if you want to know about the best books to learn data analysis, this article is for you. In this article, I will introduce you to some of the best books to learn data analysis.'

# %%
tfidfv = text.TfidfVectorizer(input=articles, stop_words='english')
tfidfv_fit = tfidfv.fit_transform(articles)

# %%
csim = cosine_similarity(tfidfv_fit)

# %%
csim
# Out:
# array([[1.        , 0.02858003, 0.02014231, ..., 0.12022323, 0.00455773,
#         0.02511323],
#        [0.02858003, 1.        , 0.07651482, ..., 0.30365338, 0.27795728,
#         0.00383369],
#        [0.02014231, 0.07651482, 1.        , ..., 0.08401534, 0.05252305,
#         0.03233971],
#        ...,
#        [0.12022323, 0.30365338, 0.08401534, ..., 1.        , 0.12620279,
#         0.04275628],
#        [0.00455773, 0.27795728, 0.05252305, ..., 0.12620279, 1.        ,
#         0.02113943],
#        [0.02511323, 0.00383369, 0.03233971, ..., 0.04275628, 0.02113943,
#         1.        ]])

# %%
def recommend_articles(x):
    return ", ".join(data["Title"].loc[x.argsort()[-5:-1]])

# %%
data["Recommended Articles"] = [recommend_articles(x) for x in uni_sim]
data.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Article  \
# ...

# %%
print(data.iloc[[4]])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Article  \
# ...

# %% [markdown]
# Index 4 contains an article on Naive Bayes algorithm and the recommended articles matches with the concept.
